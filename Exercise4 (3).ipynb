# %% [markdown]
# # Exercise 4

# %% [markdown]
# ## Instructions
#
#
# 1. Collect **100-200 images** of the fruit
# 2. Split the collected images for train, test and validation. Please make sure that there are no duplicate images. Images that are used in train should not appear in test, validation and vice versa.
# 3. Combine the collected images together with the images of apple, orange and banana. They  are already available in the link below: https://github.com/robitussin/tensorflow_lite_projects/tree/main/images/fruits
# 4. Create and train a Convolutional Neural Network (CNN).
# 5. Save the model as **"model.tflite"**
# 6. Create a folder named **exercise_4** in your **CCDEPLRL_EXERCISES_COM222_ML** repository.
# 7. Upload the **python notebook (.ipynb)** and the **model (.tflite)** in the exercise_3 folder
#
# Deadline of submission is on **April 22, 2025**

# %% [markdown]
# ## Model

# %%
# !wget https://bitbucket.org/ishaanjav/code-and-deploy-custom-tensorflow-lite-model/raw/a4febbfee178324b2083e322cdead7465d6fdf95/fruits.zip
# Out:
# --2025-04-22 08:04:16--  https://bitbucket.org/ishaanjav/code-and-deploy-custom-tensorflow-lite-model/raw/a4febbfee178324b2083e322cdead7465d6fdf95/fruits.zip
# Resolving bitbucket.org (bitbucket.org)... 13.200.41.135, 13.200.41.136, 13.200.41.134, ...
# Connecting to bitbucket.org (bitbucket.org)|13.200.41.135|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105946856 (101M) [application/zip]
# Saving to: ‘fruits.zip.2’
#
# fruits.zip.2        100%[===================>] 101.04M  17.1MB/s    in 6.2s
#
# 2025-04-22 08:04:24 (16.2 MB/s) - ‘fruits.zip.2’ saved [105946856/105946856]

# %%
# !unzip fruits.zip
# Out:
# Archive:  fruits.zip
# replace __MACOSX/._fruits? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !rm -r /content/fruits/test/eggplant

# !rm -r /content/fruits/train/eggplant

# !rm -r /content/fruits/validation/eggplant

# %% [markdown]
# Import the libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Hyperparameters: Set the image size and batch size

# %%
img_height, img_width = 32, 32
batch_size = 30

# %% [markdown]
# Split the images into train, validation and test

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/train",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/validation",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/test",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 605 files belonging to 4 classes.
# Found 88 files belonging to 4 classes.
# Found 171 files belonging to 4 classes.

# %% [markdown]
# Display sample images from the dataset

# %%
class_names = train_ds.class_names # get the actual classes from your dataset
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]]) # labels[i] is now within range
    plt.axis("off")

# %% [markdown]
# Create the Convolutional Neural Network Model (CNN)

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Rescaling(1./255),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(128, activation="relu"),
     tf.keras.layers.Dense(4)
    ]
)

# %% [markdown]
# Define the optimizer and loss function

# %%
model.compile(
    optimizer="adam",
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits = True),
    metrics=['accuracy']
)

# %% [markdown]
# Train the model

# %%
# from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %%
model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 30
)

# model.fit(train_ds, validation_data=val_ds, epochs=25, callbacks=[early_stop])
# Out:
# Epoch 1/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 6s 156ms/step - accuracy: 0.3920 - loss: 1.2995 - val_accuracy: 0.7273 - val_loss: 0.8115
# Epoch 2/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.7574 - loss: 0.6881 - val_accuracy: 0.7727 - val_loss: 0.4164
# Epoch 3/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 95ms/step - accuracy: 0.8580 - loss: 0.4301 - val_accuracy: 0.8068 - val_loss: 0.3798
# Epoch 4/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.8805 - loss: 0.3603 - val_accuracy: 0.8182 - val_loss: 0.3894
# Epoch 5/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.8869 - loss: 0.2972 - val_accuracy: 0.9318 - val_loss: 0.1925
# Epoch 6/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.8947 - loss: 0.2709 - val_accuracy: 0.9205 - val_loss: 0.1855
# Epoch 7/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9280 - loss: 0.1916 - val_accuracy: 0.9545 - val_loss: 0.1556
# Epoch 8/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 89ms/step - accuracy: 0.9585 - loss: 0.1412 - val_accuracy: 0.9432 - val_loss: 0.1833
# Epoch 9/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.9653 - loss: 0.1167 - val_accuracy: 0.9318 - val_loss: 0.1881
# Epoch 10/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 83ms/step - accuracy: 0.9743 - loss: 0.0944 - val_accuracy: 0.9545 - val_loss: 0.0847
# Epoch 11/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.9624 - loss: 0.0969 - val_accuracy: 0.9659 - val_loss: 0.1121
# Epoch 12/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9755 - loss: 0.0676 - val_accuracy: 0.9318 - val_loss: 0.1877
# Epoch 13/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - accuracy: 0.9567 - loss: 0.1147 - val_accuracy: 0.8864 - val_loss: 0.3451
# Epoch 14/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - accuracy: 0.9610 - loss: 0.1368 - val_accuracy: 0.9659 - val_loss: 0.1117
# Epoch 15/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9781 - loss: 0.0720 - val_accuracy: 0.9659 - val_loss: 0.1425
# Epoch 16/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9908 - loss: 0.0497 - val_accuracy: 0.9886 - val_loss: 0.0798
# Epoch 17/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step - accuracy: 0.9612 - loss: 0.1217 - val_accuracy: 0.9091 - val_loss: 0.2571
# Epoch 18/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.9734 - loss: 0.1040 - val_accuracy: 0.9659 - val_loss: 0.1007
# Epoch 19/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.9948 - loss: 0.0322 - val_accuracy: 0.9432 - val_loss: 0.1357
# Epoch 20/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.9783 - loss: 0.0447 - val_accuracy: 0.9886 - val_loss: 0.0481
# Epoch 21/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9814 - loss: 0.0429 - val_accuracy: 0.9659 - val_loss: 0.1255
# Epoch 22/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9934 - loss: 0.0241 - val_accuracy: 0.9545 - val_loss: 0.1126
# Epoch 23/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9991 - loss: 0.0159 - val_accuracy: 0.9432 - val_loss: 0.1656
# Epoch 24/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.9766 - loss: 0.0498 - val_accuracy: 0.9659 - val_loss: 0.1732
# Epoch 25/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9829 - loss: 0.0464 - val_accuracy: 0.9545 - val_loss: 0.1775
# Epoch 26/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - accuracy: 0.9750 - loss: 0.0555 - val_accuracy: 0.9545 - val_loss: 0.1282
# Epoch 27/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.9937 - loss: 0.0240 - val_accuracy: 0.9886 - val_loss: 0.0734
# Epoch 28/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - accuracy: 0.9916 - loss: 0.0226 - val_accuracy: 0.9886 - val_loss: 0.0300
# Epoch 29/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9917 - loss: 0.0415 - val_accuracy: 0.9886 - val_loss: 0.0646
# Epoch 30/30
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.9992 - loss: 0.0137 - val_accuracy: 0.9886 - val_loss: 0.0442

# %% [markdown]
# Test the model

# %%
model.evaluate(test_ds)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9867 - loss: 0.0261
# [0.04952842369675636, 0.9824561476707458]

# %%
import numpy

plt.figure(figsize=(10,10))
for images, labels in test_ds.take(1):
  classifications = model(images)
  # print(classifications)

  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    index = numpy.argmax(classifications[i])
    plt.title("Pred: " + class_names[index] + " | Real: " + class_names[labels[i]])

# %%
loss, accuracy = model.evaluate(test_ds)

print(f"Test accuracy: {accuracy}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9851 - loss: 0.0491
# Test accuracy: 0.9824561476707458

# %% [markdown]
# Save the model

# %%
model.save('fruitmodel.keras')

# %%
# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# tflite_model = converter.convert()

# with open("model.tflite", 'wb') as f:
#   f.write(tflite_model)
